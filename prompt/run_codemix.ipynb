# %%
import run_codemix as csnlp
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
dataset_folder = "datasets/sentimix2020/"
pretrained_name_or_path = "bert-base-multilingual-cased"

csnlp.run(
   dataset_folder=dataset_folder,
   pretrained_name_or_path=pretrained_name_or_path,
   task_type="classification",
   target_label_field="label",
   mode=["train"],
   max_epochs=5,
   batch_size=4,
   init_prompt_from_vocab=True)
# Out:
# CKPT_PATH: datasets/sentimix2020/checkpoints/2021-11-18_16:36:32.762253
# logger_file_name: datasets/sentimix2020/checkpoints/2021-11-18_16:36:32.762253/./logs/2021-11-18_16:36:32.800959
# in read_datasets_jsonl(): path:datasets/sentimix2020/train.jsonl, mode:dev, #examples:14000
# in read_datasets_jsonl(): path:datasets/sentimix2020/dev.jsonl, mode:dev, #examples:3000
# in read_datasets_jsonl(): path:datasets/sentimix2020/test.jsonl, mode:test, #examples:3000
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14000/14000 [00:00<00:00, 1329987.00it/s]
# Total tokens found: 3
# token_freq:
# {'neutral': 5264, 'negative': 4102, 'positive': 4634}
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Percent: [>              ] 0% || batch_time: 0.0499 || batch_loss: 1.0336 || avg_batch_loss: 1.0453
# /usr0/home/sumita/miniconda3/envs/codemix/lib/python3.7/site-packages/pytorch_pretrained_bert/optimization.py:275: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729138878/work/torch/csrc/utils/python_arg_parser.cpp:882.)
#   next_m.mul_(beta1).add_(1 - beta1, grad)
# Percent: [-------------->] 100% || batch_time: 0.0557 || batch_loss: 1.2324 || avg_batch_loss: 1.0352
# Percent: [-------------->] 100% || batch_time: 0.0612 || batch_loss: 0.8137 || avg_batch_loss: 1.0352
# Percent: [-------------->] 100% || batch_time: 0.0299 || batch_loss: 0.8322 || avg_batch_loss: 0.8981 || batch_acc: 0.5000 || avg_batch_acc: 0.5451
# Percent: [-------------->] 100% || batch_time: 0.0306 || batch_loss: 0.8819 || avg_batch_loss: 0.8981 || batch_acc: 0.5000 || avg_batch_acc: 0.5450
# Percent: [-------------->] 100% || batch_time: 0.0531 || batch_loss: 1.2248 || avg_batch_loss: 0.9558
# Percent: [-------------->] 100% || batch_time: 0.0579 || batch_loss: 0.7558 || avg_batch_loss: 0.9558
# Percent: [-------------->] 100% || batch_time: 0.0254 || batch_loss: 0.9609 || avg_batch_loss: 0.8446 || batch_acc: 0.7500 || avg_batch_acc: 0.5968
# Percent: [-------------->] 100% || batch_time: 0.0270 || batch_loss: 0.7208 || avg_batch_loss: 0.8445 || batch_acc: 0.7500 || avg_batch_acc: 0.5970
# Percent: [-------------->] 100% || batch_time: 0.0530 || batch_loss: 0.9530 || avg_batch_loss: 0.9330
# Percent: [-------------->] 100% || batch_time: 0.0566 || batch_loss: 0.7327 || avg_batch_loss: 0.9329
# Percent: [-------------->] 100% || batch_time: 0.0260 || batch_loss: 0.8112 || avg_batch_loss: 0.8328 || batch_acc: 0.7500 || avg_batch_acc: 0.5958
# Percent: [-------------->] 100% || batch_time: 0.0268 || batch_loss: 0.8596 || avg_batch_loss: 0.8329 || batch_acc: 0.2500 || avg_batch_acc: 0.5953
# Percent: [-------------->] 100% || batch_time: 0.0549 || batch_loss: 1.4689 || avg_batch_loss: 0.9229
# Percent: [-------------->] 100% || batch_time: 0.0641 || batch_loss: 1.0592 || avg_batch_loss: 0.9229
# Percent: [-------------->] 100% || batch_time: 0.0264 || batch_loss: 1.0295 || avg_batch_loss: 0.8166 || batch_acc: 0.5000 || avg_batch_acc: 0.6125
# Percent: [-------------->] 100% || batch_time: 0.0248 || batch_loss: 1.5172 || avg_batch_loss: 0.8175 || batch_acc: 0.2500 || avg_batch_acc: 0.6120
# Percent: [-------------->] 100% || batch_time: 0.0506 || batch_loss: 1.9818 || avg_batch_loss: 0.9120
# Percent: [-------------->] 100% || batch_time: 0.0576 || batch_loss: 0.8634 || avg_batch_loss: 0.9119
# Percent: [-------------->] 100% || batch_time: 0.0246 || batch_loss: 0.4648 || avg_batch_loss: 0.8097 || batch_acc: 1.0000 || avg_batch_acc: 0.6155
# Percent: [-------------->] 100% || batch_time: 0.0252 || batch_loss: 1.3982 || avg_batch_loss: 0.8104 || batch_acc: 0.2500 || avg_batch_acc: 0.6150
# 2021-11-18:16:36:32 INFO [run_codemix.py:61] -
#
#
# --------------------------------
# Beginning to log...
# --------------------------------
#
# 2021-11-18:16:36:32 INFO [run_codemix.py:62] - /usr0/home/sumita/miniconda3/envs/codemix/lib/python3.7/site-packages/ipykernel_launcher.py -f /usr0/home/sumita/.local/share/jupyter/runtime/kernel-a7935c54-e072-4f5a-a58c-1bcbb3650362.json
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.embeddings.word_embeddings.weight', True)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.embeddings.position_embeddings.weight', True)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.embeddings.token_type_embeddings.weight', True)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.embeddings.LayerNorm.weight', True)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.embeddings.LayerNorm.bias', True)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.attention.self.query.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.attention.self.query.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.attention.self.key.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.attention.self.key.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.attention.self.value.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.attention.self.value.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.attention.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.attention.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.attention.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.attention.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.intermediate.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.intermediate.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.0.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.attention.self.query.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.attention.self.query.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.attention.self.key.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.attention.self.key.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.attention.self.value.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.attention.self.value.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.attention.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.attention.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.attention.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.attention.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.intermediate.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.intermediate.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.1.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.attention.self.query.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.attention.self.query.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.attention.self.key.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.attention.self.key.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.attention.self.value.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.attention.self.value.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.attention.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.attention.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.attention.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.attention.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.intermediate.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.intermediate.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.2.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.attention.self.query.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.attention.self.query.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.attention.self.key.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.attention.self.key.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.attention.self.value.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.attention.self.value.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.attention.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.attention.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.attention.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.attention.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.intermediate.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.intermediate.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.3.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.attention.self.query.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.attention.self.query.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.attention.self.key.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.attention.self.key.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.attention.self.value.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.attention.self.value.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.attention.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.attention.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.attention.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.attention.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.intermediate.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.intermediate.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.4.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.attention.self.query.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.attention.self.query.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.attention.self.key.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.attention.self.key.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.attention.self.value.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.attention.self.value.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.attention.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.attention.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.attention.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.attention.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.intermediate.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.intermediate.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.5.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.attention.self.query.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.attention.self.query.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.attention.self.key.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.attention.self.key.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.attention.self.value.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.attention.self.value.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.attention.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.attention.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.attention.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.attention.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.intermediate.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.intermediate.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.6.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.attention.self.query.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.attention.self.query.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.attention.self.key.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.attention.self.key.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.attention.self.value.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.attention.self.value.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.attention.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.attention.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.attention.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.attention.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.intermediate.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.intermediate.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.7.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.attention.self.query.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.attention.self.query.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.attention.self.key.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.attention.self.key.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.attention.self.value.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.attention.self.value.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.attention.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.attention.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.attention.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.attention.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.intermediate.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.intermediate.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.8.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.attention.self.query.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.attention.self.query.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.attention.self.key.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.attention.self.key.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.attention.self.value.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.attention.self.value.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.attention.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.attention.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.attention.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.attention.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.intermediate.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.intermediate.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.9.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.attention.self.query.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.attention.self.query.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.attention.self.key.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.attention.self.key.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.attention.self.value.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.attention.self.value.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.attention.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.attention.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.attention.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.attention.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.intermediate.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.intermediate.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.10.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.attention.self.query.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.attention.self.query.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.attention.self.key.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.attention.self.key.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.attention.self.value.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.attention.self.value.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.attention.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.attention.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.attention.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.attention.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.intermediate.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.intermediate.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.output.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.output.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.output.LayerNorm.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.encoder.layer.11.output.LayerNorm.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.pooler.dense.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('model.pooler.dense.bias', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('mlp_layer.weight', True)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('mlp_layer.bias', True)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('wte.weight', False)
# 2021-11-18:16:36:42 INFO [run_codemix.py:260] - parameter name and grad_info: ('soft_prompt.weight', True)
# 2021-11-18:16:36:42 INFO [run_codemix.py:274] - 199 number of params are being optimized with BertAdam
# 2021-11-18:16:36:42 INFO [run_codemix.py:282] - 2 number of params are being optimized with Adam
# 2021-11-18:16:36:42 INFO [run_codemix.py:282] - 2 number of params are being optimized with Adam
# 2021-11-18:16:36:42 INFO [run_codemix.py:284] - number of parameters (all, trainable) in your model: (269683203, 413955)
# 2021-11-18:16:36:42 INFO [run_codemix.py:180] -
#
# ################
# 2021-11-18:16:36:42 INFO [run_codemix.py:181] - epoch: 0
# 2021-11-18:16:36:42 INFO [run_codemix.py:116] - len of train data: 14000
# 2021-11-18:16:36:42 INFO [run_codemix.py:117] - n_batches of train data: 3500
# 2021-11-18:16:40:06 INFO [run_codemix.py:148] - len of dev data: 3000
# 2021-11-18:16:40:06 INFO [run_codemix.py:149] - n_batches of dev data: 750
# 2021-11-18:16:40:27 INFO [run_codemix.py:185] -
#  Validation Complete
# 2021-11-18:16:40:27 INFO [run_codemix.py:186] - Validation avg_loss: 0.8981 and acc: 0.5450 and f1: 0.5272
# 2021-11-18:16:40:27 INFO [run_codemix.py:187] -
#               precision    recall  f1-score   support
#
#            0     0.4467    0.7009    0.5456      1100
#            1     0.5864    0.2300    0.3304       900
#            2     0.7134    0.6570    0.6840      1000
#
#     accuracy                         0.5450      3000
#    macro avg     0.5822    0.5293    0.5200      3000
# weighted avg     0.5775    0.5450    0.5272      3000
#
# 2021-11-18:16:40:44 INFO [run_codemix.py:205] - Model(s) saved in datasets/sentimix2020/checkpoints/2021-11-18_16:36:32.762253 at the end of epoch(0-base) 0
# 2021-11-18:16:40:44 INFO [run_codemix.py:180] -
#
# ################
# 2021-11-18:16:40:44 INFO [run_codemix.py:181] - epoch: 1
# 2021-11-18:16:40:44 INFO [run_codemix.py:116] - len of train data: 14000
# 2021-11-18:16:40:44 INFO [run_codemix.py:117] - n_batches of train data: 3500
# 2021-11-18:16:44:07 INFO [run_codemix.py:148] - len of dev data: 3000
# 2021-11-18:16:44:07 INFO [run_codemix.py:149] - n_batches of dev data: 750
# 2021-11-18:16:44:28 INFO [run_codemix.py:185] -
#  Validation Complete
# 2021-11-18:16:44:28 INFO [run_codemix.py:186] - Validation avg_loss: 0.8445 and acc: 0.5970 and f1: 0.5975
# 2021-11-18:16:44:28 INFO [run_codemix.py:187] -
#               precision    recall  f1-score   support
#
#            0     0.5073    0.5036    0.5055      1100
#            1     0.5658    0.5878    0.5766       900
#            2     0.7276    0.7080    0.7177      1000
#
#     accuracy                         0.5970      3000
#    macro avg     0.6002    0.5998    0.5999      3000
# weighted avg     0.5983    0.5970    0.5975      3000
#
# 2021-11-18:16:44:43 INFO [run_codemix.py:205] - Model(s) saved in datasets/sentimix2020/checkpoints/2021-11-18_16:36:32.762253 at the end of epoch(0-base) 1
# 2021-11-18:16:44:43 INFO [run_codemix.py:180] -
#
# ################
# 2021-11-18:16:44:43 INFO [run_codemix.py:181] - epoch: 2
# 2021-11-18:16:44:43 INFO [run_codemix.py:116] - len of train data: 14000
# 2021-11-18:16:44:43 INFO [run_codemix.py:117] - n_batches of train data: 3500
# 2021-11-18:16:48:07 INFO [run_codemix.py:148] - len of dev data: 3000
# 2021-11-18:16:48:07 INFO [run_codemix.py:149] - n_batches of dev data: 750
# 2021-11-18:16:48:27 INFO [run_codemix.py:185] -
#  Validation Complete
# 2021-11-18:16:48:27 INFO [run_codemix.py:186] - Validation avg_loss: 0.8329 and acc: 0.5953 and f1: 0.5898
# 2021-11-18:16:48:27 INFO [run_codemix.py:187] -
#               precision    recall  f1-score   support
#
#            0     0.5319    0.4018    0.4578      1100
#            1     0.5266    0.7467    0.6176       900
#            2     0.7525    0.6720    0.7100      1000
#
#     accuracy                         0.5953      3000
#    macro avg     0.6037    0.6068    0.5951      3000
# weighted avg     0.6039    0.5953    0.5898      3000
#
# 2021-11-18:16:48:27 INFO [run_codemix.py:207] - no improvements in results to save a checkpoint
# 2021-11-18:16:48:27 INFO [run_codemix.py:208] - checkpoint previously saved during epoch 1(0-base) at: datasets/sentimix2020/checkpoints/2021-11-18_16:36:32.762253/model.pth.tar
# 2021-11-18:16:48:27 INFO [run_codemix.py:180] -
#
# ################
# 2021-11-18:16:48:27 INFO [run_codemix.py:181] - epoch: 3
# 2021-11-18:16:48:27 INFO [run_codemix.py:116] - len of train data: 14000
# 2021-11-18:16:48:27 INFO [run_codemix.py:117] - n_batches of train data: 3500
# 2021-11-18:16:51:51 INFO [run_codemix.py:148] - len of dev data: 3000
# 2021-11-18:16:51:51 INFO [run_codemix.py:149] - n_batches of dev data: 750
# 2021-11-18:16:52:11 INFO [run_codemix.py:185] -
#  Validation Complete
# 2021-11-18:16:52:11 INFO [run_codemix.py:186] - Validation avg_loss: 0.8175 and acc: 0.6120 and f1: 0.6024
# 2021-11-18:16:52:11 INFO [run_codemix.py:187] -
#               precision    recall  f1-score   support
#
#            0     0.5560    0.4064    0.4695      1100
#            1     0.5720    0.6889    0.6250       900
#            2     0.6915    0.7690    0.7282      1000
#
#     accuracy                         0.6120      3000
#    macro avg     0.6065    0.6214    0.6076      3000
# weighted avg     0.6060    0.6120    0.6024      3000
#
# 2021-11-18:16:52:29 INFO [run_codemix.py:205] - Model(s) saved in datasets/sentimix2020/checkpoints/2021-11-18_16:36:32.762253 at the end of epoch(0-base) 3
# 2021-11-18:16:52:29 INFO [run_codemix.py:180] -
#
# ################
# 2021-11-18:16:52:29 INFO [run_codemix.py:181] - epoch: 4
# 2021-11-18:16:52:29 INFO [run_codemix.py:116] - len of train data: 14000
# 2021-11-18:16:52:29 INFO [run_codemix.py:117] - n_batches of train data: 3500
# 2021-11-18:16:55:54 INFO [run_codemix.py:148] - len of dev data: 3000
# 2021-11-18:16:55:54 INFO [run_codemix.py:149] - n_batches of dev data: 750
# 2021-11-18:16:56:14 INFO [run_codemix.py:185] -
#  Validation Complete
# 2021-11-18:16:56:14 INFO [run_codemix.py:186] - Validation avg_loss: 0.8104 and acc: 0.6150 and f1: 0.6071
# 2021-11-18:16:56:14 INFO [run_codemix.py:187] -
#               precision    recall  f1-score   support
#
#            0     0.5609    0.4018    0.4682      1100
#            1     0.5444    0.7622    0.6352       900
#            2     0.7532    0.7170    0.7346      1000
#
#     accuracy                         0.6150      3000
#    macro avg     0.6195    0.6270    0.6127      3000
# weighted avg     0.6201    0.6150    0.6071      3000
#
# 2021-11-18:16:56:30 INFO [run_codemix.py:205] - Model(s) saved in datasets/sentimix2020/checkpoints/2021-11-18_16:36:32.762253 at the end of epoch(0-base) 4
